# %%
# Step 1: Import all required libraries
import pandas as pd                     # For data handling and cleaning
from mlxtend.preprocessing import TransactionEncoder  # For one-hot encoding of transactions
from mlxtend.frequent_patterns import apriori, association_rules  # For rule mining
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# 🧹 Step 2: Load and preprocess the dataset
file_path = "Online retail.xlsx"
data = pd.read_excel(file_path, header=None)

# Assuming the data is in a single column and each row represents a transaction with items separated by commas
# Split the single column into a list of items per transaction
transactions = data[0].apply(lambda x: x.split(',') if isinstance(x, str) else []).tolist()

# Display the first 10 transactions to verify the preprocessing
display(transactions[:10])
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# Remove missing or duplicate records
data.dropna(inplace=True)
data.drop_duplicates(inplace=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# Convert each transaction (row) to a list of items
transactions = data[0].apply(lambda x: [item.strip() for item in str(x).split(',')])
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
#Step 3: Transform data for model input
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# Step 4: Apply Apriori algorithm
# Set a low min_support (3%) to keep only frequent products
frequent_itemsets = apriori(df, min_support=0.03, use_colnames=True)
frequent_itemsets.sort_values(by="support", ascending=False, inplace=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
#Step 5: Generate Association Rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
rules = rules[(rules['confidence'] >= 0.3) & (rules['lift'] > 1)]
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
#Step 6: Sort and view interesting rules
top_rules = rules.sort_values(by="lift", ascending=False)
print(top_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head(10))
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %% [markdown]
# **What is lift and why is it important in Association rules?**
# Lift measures how much more likely two items are bought together than would be expected if they were independent.
#
# Lift
# (
# A
# →
# B
# )
# =
# Confidence
# (
# A
# →
# B
# )
# Support
# (
# B
# )
# Lift(A→B)=
# Support(B)
# Confidence(A→B)
#
# A lift value greater than 1 means the presence of item A increases the likelihood of item B being purchased, indicating a strong association. Lift is important because it helps identify rules that represent true relationships rather than random co-occurrences.​
#
#
# **What is support and confidence? How do you calculate them?**
# Support is the proportion of transactions that contain both items A and B:
#
# Support
# (
# A
# ,
# B
# )
# =
# Number of transactions containing both A and B
# Total number of transactions
# Support(A,B)=
# Total number of transactions
# Number of transactions containing both A and B
#
# Confidence is the probability that item B is purchased given that item A is purchased:
#
# Confidence
# (
# A
# →
# B
# )
# =
# Support
# (
# A
# ,
# B
# )
# Support
# (
# A
# )
# Confidence(A→B)=
# Support(A)
# Support(A,B)
#
# Support shows how frequently a rule occurs, while confidence shows the reliability of the rule.​
#
#
# **What are some limitations or challenges of Association rules mining?**
# Setting appropriate thresholds for support, confidence, and lift can be difficult and may affect the quality of discovered rules.
#
# The algorithm can generate a large number of rules, many of which may be irrelevant or redundant.
#
# Association rules do not consider the order of items (unlike sequence mining) and may miss temporal patterns.
#
# Computational complexity increases with large datasets, making the process resource-intensive.

# %% [markdown]
# # Summary
# The assignment focused on applying association rule mining techniques, specifically the Apriori algorithm, to discover interesting relationships between products in retail transaction data. The process began with data preprocessing, where missing values and duplicates were removed, and transactions were converted into a suitable format for analysis. The data was then transformed into a one-hot encoded matrix, enabling the use of the Apriori algorithm to identify frequent itemsets.
#
# Association rules were generated from these itemsets, using thresholds for support, confidence, and lift to ensure the rules were meaningful and actionable. The most interesting rules were selected based on their lift values, highlighting strong associations between products frequently purchased together. The results provided insights into customer purchasing behavior, such as which products are commonly bought in combination, which can inform marketing strategies, product placement, and promotional offers.
#
# The assignment also included explanations of key concepts:
#
# Support measures how often items appear together in transactions.
#
# Confidence indicates the likelihood of purchasing one item given another.
#
# Lift shows how much more likely items are bought together than by chance.
#
# Finally, the solution addressed common challenges in association rule mining, such as the generation of too many rules and the need for careful interpretation, ensuring the analysis was both robust and practical for real-world reta
